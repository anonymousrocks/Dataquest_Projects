# %%
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
recent_grads = pd.read_csv("recent-grads.csv")
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  ...  \
# 168    Biology & Life Science    0.637293           47      6259  ...
# 169  Psychology & Social Work    0.817099            7      2125  ...
# 170  Psychology & Social Work    0.799859           13      2101  ...
# 171  Psychology & Social Work    0.798746           21      3777  ...
# 172                 Education    0.877960            2       742  ...
#
#      Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = len(recent_grads)
raw_data_count
# Out:
# 173

# %%
recent_grads = recent_grads.dropna()

# %%
cleaned_data_count = len(recent_grads)
cleaned_data_count
# Out:
# 172

# %%
fig, axes = plt.subplots(nrows= 3, ncols = 2, figsize = (10,20))
ax1 = recent_grads.plot(ax = axes[0,0], x="Sample_size", y = "Median", kind = "scatter",
                        rot = 90, title = "Sample Size vs Salary")
ax2 = recent_grads.plot(ax = axes[0,1], x = "Sample_size", y= "Unemployment_rate", kind = "scatter"
                       , rot = 90, title = "Sample Size vs Unemployment Rate")
ax3 = recent_grads.plot(ax = axes[1,0], x= "Full_time", y = "Median", kind = "scatter",
                        rot = 90 , title = " Full time employess (n) vs Median Salary")
ax4= recent_grads.plot( ax = axes[1,1], x= "ShareWomen", y="Unemployment_rate", kind = "scatter", 
                       rot = 90, title = "Women Proportion vs Unemployment Rate")
ax5 = recent_grads.plot( ax = axes[2,0], x = "Men", y="Median", kind = "scatter", 
                       rot = 90, title = "Men vs Salary")
ax6 = recent_grads.plot( ax = axes[2,1], x="Women", y= "Median", kind = "scatter",
                       rot = 90, title = "Women vs Salary")
plt.show()

# %% [markdown]
# ### Do Students in more popular majors make more money ?

# %%
ax1 = recent_grads.plot(x="Total", y = "Median", kind = "scatter", rot = 90)
ax1.set_title("Total Student per Major vs Salary")
# Out:
# Text(0.5, 1.0, 'Total Student per Major vs Salary')

# %% [markdown]
# This result shows that it has no feasible correlation between total student per major with salary

# %% [markdown]
# ### Do Students that majored in subjects that were majority female make more money?

# %%
ax2= recent_grads.plot( x= "ShareWomen", y="Median", kind = "scatter", 
                       rot = 90, title = "Women Proportion vs Median")

# %% [markdown]
# This have a very small correlation as the increase in share of women earn less money

# %% [markdown]
# ### Is there any link between the number of full-time employees and median salary?

# %%
ax3 = recent_grads.plot( x= "Full_time", y = "Median", kind = "scatter", rot = 90 , title = " Full time employess (n) vs Median Salary")

# %% [markdown]
# Based on this scatter plot, it is found out that there is not correlation between number of full time employess and median salary

# %% [markdown]
# ### Histogram

# %%
recent_grads["Sample_size"].describe()
# Out:
# count     172.000000
# mean      357.941860
# std       619.680419
# min         2.000000
# 25%        42.000000
# 50%       131.000000
# 75%       339.000000
# max      4212.000000
# Name: Sample_size, dtype: float64

# %%
recent_grads["Sample_size"].hist(bins= 25,
                                 range =(0,5000)).set_title("Sample Size")
# Out:
# Text(0.5, 1.0, 'Sample Size')

# %% [markdown]
# As it can be seen that the sample size is higher in 0-1000

# %%
recent_grads["Median"].describe()
# Out:
# count       172.000000
# mean      40076.744186
# std       11461.388773
# min       22000.000000
# 25%       33000.000000
# 50%       36000.000000
# 75%       45000.000000
# max      110000.000000
# Name: Median, dtype: float64

# %%
recent_grads["Median"].hist(bins= 25,
                                 range =(20000,110000)).set_title("Median")
# Out:
# Text(0.5, 1.0, 'Median')

# %% [markdown]
# For the salary, the majority is between 20,000 to 40,000

# %%
recent_grads["Employed"].describe()
# Out:
# count       172.00000
# mean      31355.80814
# std       50777.42865
# min           0.00000
# 25%        3734.75000
# 50%       12031.50000
# 75%       31701.25000
# max      307933.00000
# Name: Employed, dtype: float64

# %%
recent_grads["Employed"].hist(bins= 25,
                                 range =(0,310000)).set_title("Employed")
# Out:
# Text(0.5, 1.0, 'Employed')

# %% [markdown]
# For the recent grads who is employed, it's majority ranging between 0 - 50,000

# %%
recent_grads["Full_time"].describe()
# Out:
# count       172.000000
# mean      26165.767442
# std       42957.122320
# min         111.000000
# 25%        3181.000000
# 50%       10073.500000
# 75%       25447.250000
# max      251540.000000
# Name: Full_time, dtype: float64

# %%
recent_grads["Full_time"].hist(bins = 25, range = (100,252000)).set_title("Full Time")
# Out:
# Text(0.5, 1.0, 'Full Time')

# %% [markdown]
# For the recent grads, the majority of them who is employed in full time job is majority ranging between 0 - 50,000

# %%
recent_grads["ShareWomen"].describe()
# Out:
# count    172.000000
# mean       0.522223
# std        0.231205
# min        0.000000
# 25%        0.336026
# 50%        0.534024
# 75%        0.703299
# max        0.968954
# Name: ShareWomen, dtype: float64

# %%
recent_grads["ShareWomen"].hist(bins= 25, range = (0,1),grid = False).set_title("Share Women")
# Out:
# Text(0.5, 1.0, 'Share Women')

# %% [markdown]
# The share of women from the recent grads are majority in range between 0.2 to 0.8

# %%
recent_grads["Unemployment_rate"].describe()
# Out:
# count    172.000000
# mean       0.068024
# std        0.030340
# min        0.000000
# 25%        0.050261
# 50%        0.067544
# 75%        0.087247
# max        0.177226
# Name: Unemployment_rate, dtype: float64

# %%
recent_grads["Unemployment_rate"].hist(bins= 25, range = (0,0.18), grid = False).set_title("Unemployment Rate")
# Out:
# Text(0.5, 1.0, 'Unemployment Rate')

# %% [markdown]
# The unemployment rate from the recent graduates are majority ranging from 0.50 to 0.75

# %%
recent_grads["Men"].describe()
# Out:
# count       172.000000
# mean      16723.406977
# std       28122.433474
# min         119.000000
# 25%        2177.500000
# 50%        5434.000000
# 75%       14631.000000
# max      173809.000000
# Name: Men, dtype: float64

# %%
recent_grads["Men"].hist(bins= 25, range = (0, 174000), grid = False).set_title("Men")
# Out:
# Text(0.5, 1.0, 'Men')

# %% [markdown]
# The total men in the recent graduates are majority ranging between 0 - 25,000

# %%
recent_grads["Women"].describe()
# Out:
# count       172.000000
# mean      22646.674419
# std       41057.330740
# min           0.000000
# 25%        1778.250000
# 50%        8386.500000
# 75%       22553.750000
# max      307087.000000
# Name: Women, dtype: float64

# %%
recent_grads["Women"].hist(bins= 25, range = (0, 310000), grid = False).set_title("Women")
# Out:
# Text(0.5, 1.0, 'Women')

# %% [markdown]
# The total women in the recent grads are majority ranging between 0-50,000

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[["Sample_size","Median"]], figsize =(10,10))
# Out:
# array([[<AxesSubplot:xlabel='Sample_size', ylabel='Sample_size'>,
#         <AxesSubplot:xlabel='Median', ylabel='Sample_size'>],
#        [<AxesSubplot:xlabel='Sample_size', ylabel='Median'>,
#         <AxesSubplot:xlabel='Median', ylabel='Median'>]], dtype=object)

# %% [markdown]
# From the scatter matrix, it is found out that either sample size as independent or dependent, it has no correlation with salary

# %%
scatter_matrix(recent_grads[["Sample_size","Median","Unemployment_rate"]], figsize =(10,10))
# Out:
# array([[<AxesSubplot:xlabel='Sample_size', ylabel='Sample_size'>,
#         <AxesSubplot:xlabel='Median', ylabel='Sample_size'>,
#         <AxesSubplot:xlabel='Unemployment_rate', ylabel='Sample_size'>],
#        [<AxesSubplot:xlabel='Sample_size', ylabel='Median'>,
#         <AxesSubplot:xlabel='Median', ylabel='Median'>,
#         <AxesSubplot:xlabel='Unemployment_rate', ylabel='Median'>],
#        [<AxesSubplot:xlabel='Sample_size', ylabel='Unemployment_rate'>,
#         <AxesSubplot:xlabel='Median', ylabel='Unemployment_rate'>,
#         <AxesSubplot:xlabel='Unemployment_rate', ylabel='Unemployment_rate'>]],
#       dtype=object)

# %% [markdown]
# From the scatter matrix above it is found out that neither sample size as the independet and dependent for both median and unemployment rate has correlation with each other

# %%
fig = plt.figure(figsize = (10,10))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)
recent_grads[:10].plot.bar(ax = ax1 , x = "Major", y = "ShareWomen", title = "First 10 Women")
ax2 = recent_grads[-10:].plot.bar(ax = ax2 , x = "Major", y ="ShareWomen", title ="Last 10 Women")
plt.show()

# %% [markdown]
# It is found at that overall, thelast 10 of major ranking, have more share of women

# %%
fig = plt.figure(figsize = (10,10))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)
recent_grads[:10].plot.bar(ax = ax1 , x = "Major", y = "Unemployment_rate", title = "Unemployment Rate")
ax2 = recent_grads[-10:].plot.bar(ax = ax2 , x = "Major", y ="Unemployment_rate", title ="Unemployment Rate")
plt.show()

# %% [markdown]
# For the unemployment rate, in the last 10 rank of the major, it has higher unemployment rate compare to the first 10 rank of major

# %%
recent_grads.groupby("Major_category").sum().plot.bar(y = ["Men","Women"], title= "Men and Women in each Major Categories")
# Out:
# <AxesSubplot:title={'center':'Men and Women in each Major Categories'}, xlabel='Major_category'>

# %% [markdown]
# It is found out that overall, the total number of women students are more than male students. However, in business major, the man proportion is slightly bigger than women proportion

# %%
recent_grads.boxplot("Median", grid = False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# As the salary box plot shows that the median is positively skewed where the mean will be much higher than the median

# %%
recent_grads.boxplot("Unemployment_rate", grid = False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# As the unemployment rate box plot shows that the median is normally dstributed in between 5%  to 7.5%

# %%
fig, axes = plt.subplots(nrows= 3, ncols = 2, figsize = (10,20))
ax1 = recent_grads.plot(ax = axes[0,0], x="Sample_size", y = "Median", kind = "hexbin",
                        rot = 90, title = "Sample Size vs Salary", cmap = "viridis")
ax2 = recent_grads.plot(ax = axes[0,1], x = "Sample_size", y= "Unemployment_rate", kind = "hexbin"
                       , rot = 90, title = "Sample Size vs Unemployment Rate", cmap = "viridis")
ax3 = recent_grads.plot(ax = axes[1,0], x= "Full_time", y = "Median", kind = "hexbin",
                        rot = 90 , title = " Full time employess (n) vs Median Salary", cmap = "viridis")
ax4= recent_grads.plot( ax = axes[1,1], x= "ShareWomen", y="Unemployment_rate", kind = "hexbin", 
                       rot = 90, title = "Women Proportion vs Unemployment Rate",cmap = "viridis")
ax5 = recent_grads.plot( ax = axes[2,0], x = "Men", y="Median", kind = "hexbin", 
                       rot = 90, title = "Men vs Salary",cmap = "viridis")
ax6 = recent_grads.plot( ax = axes[2,1], x="Women", y= "Median", kind = "hexbin",
                       rot = 90, title = "Women vs Salary",cmap = "viridis")
plt.show()

# %% [markdown]
# There is no feasible correlation in all of the hexbin above.
